# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
import os

# %%
model_mn2 = MobileNetV2(
    input_shape=None, alpha=1.0, include_top=True, weights='imagenet',
    input_tensor=None, pooling=None, classes=1000
)

# %%
layer_name = 'block_15_add'
feature_extractor = Model(inputs=model_mn2.input, outputs=model_mn2.get_layer(layer_name).output)

# %%
for set_kind in ['train', 'val', 'test']:
    source_dir = 'datasets/augmented/PlantVillage/' + set_kind
    dest_dir = 'datasets/encoded/PlantVillage/' + set_kind

    for i, directory in enumerate(os.listdir(source_dir)):
        print(f"\r[{i}] {source_dir}/{directory}", end='')
        results = []
        dump = []

        for i, file in enumerate(os.listdir(f"{source_dir}/{directory}")):
            image = tf.keras.preprocessing.image.load_img(f"{source_dir}/{directory}/{file}")
            x = tf.keras.preprocessing.image.img_to_array(image)
            dump += [x]

        preprocessed = tf.keras.applications.mobilenet_v2.preprocess_input(np.array(dump))
        del dump
        dataset = tf.data.Dataset.from_tensor_slices(preprocessed)
        del preprocessed
        dataset = dataset.batch(100)

        for batch in dataset:
            results += [feature_extractor.predict(batch)]

        results = np.concatenate(results, axis=0)
        np.save(f"{dest_dir}/{directory}.npy", results)
        del results
        del dataset

# %%
for set_kind in ['train', 'val', 'test']:
    source_dir = 'datasets/augmented/PlantDoc/' + set_kind
    dest_dir = 'datasets/encoded/PlantDoc/' + set_kind

    for i, directory in enumerate(os.listdir(source_dir)):
        print(f"\r[{i}] {source_dir}/{directory}", end='')
        results = []
        dump = []

        for i, file in enumerate(os.listdir(f"{source_dir}/{directory}")):
            image = tf.keras.preprocessing.image.load_img(f"{source_dir}/{directory}/{file}")
            x = tf.keras.preprocessing.image.img_to_array(image)
            dump += [x]

        preprocessed = tf.keras.applications.mobilenet_v2.preprocess_input(np.array(dump))
        del dump
        dataset = tf.data.Dataset.from_tensor_slices(preprocessed)
        del preprocessed
        dataset = dataset.batch(100)

        for batch in dataset:
            results += [feature_extractor.predict(batch)]

        results = np.concatenate(results, axis=0)
        np.save(f"{dest_dir}/{directory}.npy", results)
        del results
        del dataset
# Out:
# 4/4 [==============================] - 6s 117ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 3/3 [==============================] - 0s 189ms/step
# 4/4 [==============================] - 0s 55ms/stepaf
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 3/3 [==============================] - 0s 169ms/step
# 4/4 [==============================] - 0s 52ms/stepaf
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 3/3 [==============================] - 0s 175ms/step
# 4/4 [==============================] - 0s 49ms/stepeaf
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 360ms/step
# 4/4 [==============================] - 0s 53ms/stepeaf spot
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 406ms/step
# 4/4 [==============================] - 0s 50ms/stepf
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 3/3 [==============================] - 0s 227ms/step
# 4/4 [==============================] - 0s 52ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 38ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 321ms/step
# 4/4 [==============================] - 0s 42ms/stepf spot
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 385ms/step
# 4/4 [==============================] - 0s 46ms/stepght
# 4/4 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 401ms/step
# 4/4 [==============================] - 0s 55ms/stepf
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 3/3 [==============================] - 0s 218ms/step
# 4/4 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 1s 531ms/step
# 4/4 [==============================] - 0s 33ms/steplack rot
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 33ms/step
# 3/3 [==============================] - 0s 211ms/step
# 4/4 [==============================] - 0s 53ms/stepearly blight
# 4/4 [==============================] - 0s 38ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 3/3 [==============================] - 0s 228ms/step
# 4/4 [==============================] - 0s 65ms/steplate blight
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 0s 33ms/step
# 3/3 [==============================] - 0s 215ms/step
# 4/4 [==============================] - 0s 56ms/stepaf
# 4/4 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 3/3 [==============================] - 1s 254ms/step
# 4/4 [==============================] - 0s 55ms/stepf
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 31ms/stepry mildew leaf
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 336ms/step
# 4/4 [==============================] - 0s 125ms/stepaf
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 3/3 [==============================] - 0s 186ms/step
# 4/4 [==============================] - 0s 105ms/stepblight leaf
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 3/3 [==============================] - 0s 168ms/step
# 4/4 [==============================] - 0s 91ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 359ms/step
# 4/4 [==============================] - 0s 131ms/stepacterial spot
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 39ms/step
# 3/3 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 131ms/stepate blight
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 34ms/step
# 3/3 [==============================] - 0s 53ms/step
# 4/4 [==============================] - 0s 123ms/steposaic virus
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 129ms/stepellow virus
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 120ms/stepeaf
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 31ms/step
# 3/3 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 112ms/stepia leaf spot
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 32ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/stepf
# 1/1 [==============================] - 0s 319ms/step spot
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 327ms/steppot
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/stepck rot
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/steprly blight
# 1/1 [==============================] - 0s 28ms/stepte blight
# 1/1 [==============================] - 0s 360ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step mildew leaf
# 1/1 [==============================] - 0s 26ms/stepf
# 1/1 [==============================] - 0s 27ms/steplight leaf
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/stepcterial spot
# 1/1 [==============================] - 0s 27ms/stepte blight
# 1/1 [==============================] - 0s 29ms/stepsaic virus
# 1/1 [==============================] - 0s 26ms/stepllow virus
# 1/1 [==============================] - 0s 26ms/stepaf
# 1/1 [==============================] - 0s 31ms/stepa leaf spot
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/stepf
# 1/1 [==============================] - 0s 25ms/stepf
# 1/1 [==============================] - 0s 26ms/stepaf
# 1/1 [==============================] - 0s 24ms/stepaf spot
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step spot
# 1/1 [==============================] - 0s 25ms/stepht
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/stepack rot
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/steparly blight
# 1/1 [==============================] - 0s 24ms/stepate blight
# 1/1 [==============================] - 0s 25ms/stepf
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/stepy mildew leaf
# 1/1 [==============================] - 0s 25ms/stepaf
# 1/1 [==============================] - 0s 26ms/stepblight leaf
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/stepacterial spot
# 1/1 [==============================] - 0s 25ms/stepate blight
# 1/1 [==============================] - 0s 27ms/steposaic virus
# 1/1 [==============================] - 0s 24ms/stepellow virus
# 1/1 [==============================] - 0s 24ms/stepeaf
# 1/1 [==============================] - 0s 25ms/stepia leaf spot
