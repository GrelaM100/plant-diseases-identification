# %%
from utils import CLASS_TO_ID
from transformers import ViTFeatureExtractor, ViTForImageClassification, TrainingArguments, Trainer
import torch
import numpy as np
from datasets import load_metric, load_dataset

# %%
train = load_dataset('datasets/augmented/PlantVillage/train')
val = load_dataset('datasets/augmented/PlantVillage/val')
train = train.shuffle(seed=42)
# Out:
# Resolving data files:   0%|          | 0/46541 [00:00<?, ?it/s]
# Using custom data configuration train-4a5d2e024927d5d3
# Found cached dataset imagefolder (C:/Users/ASROCK/.cache/huggingface/datasets/imagefolder/train-4a5d2e024927d5d3/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f)
# Using custom data configuration val-c4c340b5bde682f0
# Found cached dataset imagefolder (C:/Users/ASROCK/.cache/huggingface/datasets/imagefolder/val-c4c340b5bde682f0/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f)
# Loading cached shuffled indices for dataset at C:/Users/ASROCK/.cache/huggingface/datasets/imagefolder/train-4a5d2e024927d5d3/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f\cache-9c9db930684d816b.arrow
#   0%|          | 0/1 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/11096 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
model_name_or_path = 'WinKawaks/vit-tiny-patch16-224'
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name_or_path)

# %%
def transform(example_batch):
    inputs = feature_extractor([x for x in example_batch['image']], return_tensors='pt')
    inputs['labels'] = example_batch['label']

    return inputs

def collate_fn(batch):
    return {
        'pixel_values': torch.stack([x['pixel_values'] for x in batch]),
        'labels': torch.tensor([x['labels'] for x in batch])
    }

metric = load_metric("accuracy")
def compute_metrics(p):
    return metric.compute(predictions=np.argmax(p.predictions, axis=1), references=p.label_ids)

prepared_train = train.with_transform(transform)
prepared_val = train.with_transform(transform)
# Out:
# C:\Users\ASROCK\AppData\Local\Temp\ipykernel_8620\4244057976.py:13: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("accuracy")

# %%
model = ViTForImageClassification.from_pretrained(
    model_name_or_path,
    num_labels=len(CLASS_TO_ID),
    id2label={y: x for x, y in CLASS_TO_ID.items()},
    label2id=CLASS_TO_ID,
    ignore_mismatched_sizes=True
)

training_args = TrainingArguments(
  output_dir="./vit-base-plant-village",
  per_device_train_batch_size=8,
  evaluation_strategy="steps",
  num_train_epochs=5,
  fp16=True,
  save_steps=100,
  eval_steps=100,
  logging_steps=10,
  learning_rate=2e-4,
  save_total_limit=2,
  remove_unused_columns=False,
  push_to_hub=False,
  load_best_model_at_end=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=collate_fn,
    compute_metrics=compute_metrics,
    train_dataset=prepared_train['train'],
    eval_dataset=prepared_val['train'],
    tokenizer=feature_extractor,
)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at WinKawaks/vit-tiny-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([1000, 192]) in the checkpoint and torch.Size([39, 192]) in the model instantiated
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([39]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using cuda_amp half precision backend

# %%
train_results = trainer.train()
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
# C:\Users\ASROCK\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\transformers\optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 46541
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 29090
#   Number of trainable parameters = 5531943
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-100
# Configuration saved in ./vit-base-plant-village\checkpoint-100\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-100\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-100\preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-200
# Configuration saved in ./vit-base-plant-village\checkpoint-200\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-200\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-200\preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-300
# Configuration saved in ./vit-base-plant-village\checkpoint-300\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-300\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-300\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-400
# Configuration saved in ./vit-base-plant-village\checkpoint-400\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-400\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-500
# Configuration saved in ./vit-base-plant-village\checkpoint-500\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-500\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-500\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-600
# Configuration saved in ./vit-base-plant-village\checkpoint-600\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-600\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-600\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-700
# Configuration saved in ./vit-base-plant-village\checkpoint-700\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-700\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-700\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-800
# Configuration saved in ./vit-base-plant-village\checkpoint-800\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-800\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-800\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-900
# Configuration saved in ./vit-base-plant-village\checkpoint-900\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-900\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-900\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-1000
# Configuration saved in ./vit-base-plant-village\checkpoint-1000\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-1000\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-1000\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-1100
# Configuration saved in ./vit-base-plant-village\checkpoint-1100\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-1100\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-1100\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-1000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-1200
# Configuration saved in ./vit-base-plant-village\checkpoint-1200\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-1200\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-1200\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-1100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-1300
# Configuration saved in ./vit-base-plant-village\checkpoint-1300\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-1300\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-1300\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-1200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-1400
# Configuration saved in ./vit-base-plant-village\checkpoint-1400\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-1400\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-1400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-1300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-1500
# Configuration saved in ./vit-base-plant-village\checkpoint-1500\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-1500\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-1500\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-1400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-1600
# Configuration saved in ./vit-base-plant-village\checkpoint-1600\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-1600\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-1600\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-1700
# Configuration saved in ./vit-base-plant-village\checkpoint-1700\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-1700\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-1700\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-1500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-1800
# Configuration saved in ./vit-base-plant-village\checkpoint-1800\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-1800\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-1800\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-1600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-1900
# Configuration saved in ./vit-base-plant-village\checkpoint-1900\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-1900\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-1900\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-1700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-2000
# Configuration saved in ./vit-base-plant-village\checkpoint-2000\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-2000\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-2000\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-1800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-2100
# Configuration saved in ./vit-base-plant-village\checkpoint-2100\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-2100\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-2100\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-1900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-2200
# Configuration saved in ./vit-base-plant-village\checkpoint-2200\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-2200\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-2200\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-2100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-2300
# Configuration saved in ./vit-base-plant-village\checkpoint-2300\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-2300\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-2300\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-2200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-2400
# Configuration saved in ./vit-base-plant-village\checkpoint-2400\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-2400\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-2400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-2300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-2500
# Configuration saved in ./vit-base-plant-village\checkpoint-2500\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-2500\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-2500\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-2400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-2600
# Configuration saved in ./vit-base-plant-village\checkpoint-2600\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-2600\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-2600\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-2500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-2700
# Configuration saved in ./vit-base-plant-village\checkpoint-2700\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-2700\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-2700\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-2600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-2800
# Configuration saved in ./vit-base-plant-village\checkpoint-2800\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-2800\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-2800\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-2000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-2900
# Configuration saved in ./vit-base-plant-village\checkpoint-2900\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-2900\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-2900\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-2700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-3000
# Configuration saved in ./vit-base-plant-village\checkpoint-3000\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-3000\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-3000\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-2900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-3100
# Configuration saved in ./vit-base-plant-village\checkpoint-3100\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-3100\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-3100\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-3000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-3200
# Configuration saved in ./vit-base-plant-village\checkpoint-3200\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-3200\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-3200\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-3100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-3300
# Configuration saved in ./vit-base-plant-village\checkpoint-3300\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-3300\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-3300\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-3200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-3400
# Configuration saved in ./vit-base-plant-village\checkpoint-3400\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-3400\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-3400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-3300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-3500
# Configuration saved in ./vit-base-plant-village\checkpoint-3500\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-3500\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-3500\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-3400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-3600
# Configuration saved in ./vit-base-plant-village\checkpoint-3600\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-3600\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-3600\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-3500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-3700
# Configuration saved in ./vit-base-plant-village\checkpoint-3700\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-3700\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-3700\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-3600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-3800
# Configuration saved in ./vit-base-plant-village\checkpoint-3800\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-3800\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-3800\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-3700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-3900
# Configuration saved in ./vit-base-plant-village\checkpoint-3900\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-3900\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-3900\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-3800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-4000
# Configuration saved in ./vit-base-plant-village\checkpoint-4000\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-4000\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-4000\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-3900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-4100
# Configuration saved in ./vit-base-plant-village\checkpoint-4100\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-4100\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-4100\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-2800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-4200
# Configuration saved in ./vit-base-plant-village\checkpoint-4200\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-4200\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-4200\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-4000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-4300
# Configuration saved in ./vit-base-plant-village\checkpoint-4300\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-4300\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-4300\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-4200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-4400
# Configuration saved in ./vit-base-plant-village\checkpoint-4400\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-4400\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-4400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-4300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-4500
# Configuration saved in ./vit-base-plant-village\checkpoint-4500\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-4500\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-4500\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-4400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-4600
# Configuration saved in ./vit-base-plant-village\checkpoint-4600\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-4600\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-4600\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-4500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-4700
# Configuration saved in ./vit-base-plant-village\checkpoint-4700\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-4700\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-4700\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-4600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-4800
# Configuration saved in ./vit-base-plant-village\checkpoint-4800\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-4800\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-4800\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-4700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-4900
# Configuration saved in ./vit-base-plant-village\checkpoint-4900\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-4900\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-4900\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-4800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-5000
# Configuration saved in ./vit-base-plant-village\checkpoint-5000\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-5000\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-5000\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-4100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-5100
# Configuration saved in ./vit-base-plant-village\checkpoint-5100\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-5100\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-5100\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-4900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-5200
# Configuration saved in ./vit-base-plant-village\checkpoint-5200\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-5200\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-5200\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-5000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-5300
# Configuration saved in ./vit-base-plant-village\checkpoint-5300\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-5300\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-5300\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-5100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-5400
# Configuration saved in ./vit-base-plant-village\checkpoint-5400\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-5400\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-5400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-5200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-5500
# Configuration saved in ./vit-base-plant-village\checkpoint-5500\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-5500\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-5500\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-5300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-5600
# Configuration saved in ./vit-base-plant-village\checkpoint-5600\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-5600\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-5600\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-5500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-5700
# Configuration saved in ./vit-base-plant-village\checkpoint-5700\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-5700\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-5700\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-5600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-5800
# Configuration saved in ./vit-base-plant-village\checkpoint-5800\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-5800\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-5800\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-5700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-5900
# Configuration saved in ./vit-base-plant-village\checkpoint-5900\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-5900\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-5900\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-5800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-6000
# Configuration saved in ./vit-base-plant-village\checkpoint-6000\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-6000\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-6000\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-5900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-6100
# Configuration saved in ./vit-base-plant-village\checkpoint-6100\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-6100\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-6100\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-5400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-6200
# Configuration saved in ./vit-base-plant-village\checkpoint-6200\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-6200\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-6200\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-6000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-6300
# Configuration saved in ./vit-base-plant-village\checkpoint-6300\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-6300\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-6300\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-6200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-6400
# Configuration saved in ./vit-base-plant-village\checkpoint-6400\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-6400\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-6400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-6300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-6500
# Configuration saved in ./vit-base-plant-village\checkpoint-6500\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-6500\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-6500\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-6400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-6600
# Configuration saved in ./vit-base-plant-village\checkpoint-6600\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-6600\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-6600\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-6500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-6700
# Configuration saved in ./vit-base-plant-village\checkpoint-6700\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-6700\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-6700\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-6600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-6800
# Configuration saved in ./vit-base-plant-village\checkpoint-6800\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-6800\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-6800\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-6700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-6900
# Configuration saved in ./vit-base-plant-village\checkpoint-6900\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-6900\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-6900\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-6800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-7000
# Configuration saved in ./vit-base-plant-village\checkpoint-7000\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-7000\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-7000\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-6900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-7100
# Configuration saved in ./vit-base-plant-village\checkpoint-7100\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-7100\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-7100\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-7000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-7200
# Configuration saved in ./vit-base-plant-village\checkpoint-7200\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-7200\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-7200\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-7100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-7300
# Configuration saved in ./vit-base-plant-village\checkpoint-7300\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-7300\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-7300\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-7200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-7400
# Configuration saved in ./vit-base-plant-village\checkpoint-7400\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-7400\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-7400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-7300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-7500
# Configuration saved in ./vit-base-plant-village\checkpoint-7500\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-7500\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-7500\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-7400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-7600
# Configuration saved in ./vit-base-plant-village\checkpoint-7600\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-7600\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-7600\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-7500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-7700
# Configuration saved in ./vit-base-plant-village\checkpoint-7700\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-7700\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-7700\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-7600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-7800
# Configuration saved in ./vit-base-plant-village\checkpoint-7800\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-7800\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-7800\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-7700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-7900
# Configuration saved in ./vit-base-plant-village\checkpoint-7900\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-7900\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-7900\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-7800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-8000
# Configuration saved in ./vit-base-plant-village\checkpoint-8000\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-8000\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-8000\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-7900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-8100
# Configuration saved in ./vit-base-plant-village\checkpoint-8100\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-8100\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-8100\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-8000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-8200
# Configuration saved in ./vit-base-plant-village\checkpoint-8200\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-8200\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-8200\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-8100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-8300
# Configuration saved in ./vit-base-plant-village\checkpoint-8300\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-8300\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-8300\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-8200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-8400
# Configuration saved in ./vit-base-plant-village\checkpoint-8400\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-8400\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-8400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-8300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-8500
# Configuration saved in ./vit-base-plant-village\checkpoint-8500\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-8500\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-8500\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-8400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-8600
# Configuration saved in ./vit-base-plant-village\checkpoint-8600\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-8600\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-8600\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-8500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-8700
# Configuration saved in ./vit-base-plant-village\checkpoint-8700\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-8700\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-8700\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-8600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-8800
# Configuration saved in ./vit-base-plant-village\checkpoint-8800\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-8800\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-8800\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-8700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-8900
# Configuration saved in ./vit-base-plant-village\checkpoint-8900\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-8900\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-8900\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-8800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-9000
# Configuration saved in ./vit-base-plant-village\checkpoint-9000\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-9000\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-9000\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-8900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-9100
# Configuration saved in ./vit-base-plant-village\checkpoint-9100\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-9100\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-9100\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-9000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-9200
# Configuration saved in ./vit-base-plant-village\checkpoint-9200\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-9200\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-9200\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-9100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-9300
# Configuration saved in ./vit-base-plant-village\checkpoint-9300\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-9300\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-9300\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-9200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-9400
# Configuration saved in ./vit-base-plant-village\checkpoint-9400\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-9400\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-9400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-9300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-9500
# Configuration saved in ./vit-base-plant-village\checkpoint-9500\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-9500\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-9500\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-9400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-9600
# Configuration saved in ./vit-base-plant-village\checkpoint-9600\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-9600\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-9600\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-9500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-9700
# Configuration saved in ./vit-base-plant-village\checkpoint-9700\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-9700\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-9700\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-9600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-9800
# Configuration saved in ./vit-base-plant-village\checkpoint-9800\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-9800\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-9800\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-9700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-9900
# ...
# Image processor saved in ./vit-base-plant-village\checkpoint-10400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-10300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-10500
# Configuration saved in ./vit-base-plant-village\checkpoint-10500\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-10500\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-10500\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-10400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-10600
# Configuration saved in ./vit-base-plant-village\checkpoint-10600\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-10600\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-10600\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-10500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-10700
# Configuration saved in ./vit-base-plant-village\checkpoint-10700\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-10700\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-10700\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-10600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-10800
# Configuration saved in ./vit-base-plant-village\checkpoint-10800\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-10800\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-10800\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-10700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-10900
# Configuration saved in ./vit-base-plant-village\checkpoint-10900\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-10900\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-10900\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-10800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-11000
# Configuration saved in ./vit-base-plant-village\checkpoint-11000\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-11000\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-11000\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-10900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-11100
# Configuration saved in ./vit-base-plant-village\checkpoint-11100\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-11100\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-11100\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-11000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-11200
# Configuration saved in ./vit-base-plant-village\checkpoint-11200\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-11200\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-11200\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-6100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-11300
# Configuration saved in ./vit-base-plant-village\checkpoint-11300\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-11300\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-11300\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-11100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
# Saving model checkpoint to ./vit-base-plant-village\checkpoint-11400
# Configuration saved in ./vit-base-plant-village\checkpoint-11400\config.json
# Model weights saved in ./vit-base-plant-village\checkpoint-11400\pytorch_model.bin
# Image processor saved in ./vit-base-plant-village\checkpoint-11400\preprocessor_config.json
# Deleting older checkpoint [vit-base-plant-village\checkpoint-11300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 46541
#   Batch size = 8
#     <div>
#
#       <progress value='2' max='29090' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [    2/29090 : < :, Epoch 0.00/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train_results = trainer.train()
#       2 trainer.save_model()
#       3 trainer.log_metrics("train", train_results.metrics)
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\transformers\trainer.py:1527, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1522     self.model_wrapped = self.model
#    1524 inner_training_loop = find_executable_batch_size(
#    1525     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1526 )
# -> 1527 return inner_training_loop(
#    1528     args=args,
#    1529     resume_from_checkpoint=resume_from_checkpoint,
#    1530     trial=trial,
#    1531     ignore_keys_for_eval=ignore_keys_for_eval,
#    1532 )
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\transformers\trainer.py:1852, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1849     self.state.epoch = epoch + (step + 1) / steps_in_epoch
#    1850     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
# -> 1852     self._maybe_log_save_evaluate(tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1853 else:
#    1854     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\transformers\trainer.py:2115, in Trainer._maybe_log_save_evaluate(self, tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    2109             metrics = self.evaluate(
#    2110                 eval_dataset=eval_dataset,
#    2111                 ignore_keys=ignore_keys_for_eval,
#    2112                 metric_key_prefix=f"eval_{eval_dataset_name}",
#    2113             )
#    2114     else:
# -> 2115         metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)
#    2116     self._report_to_hp_search(trial, self.state.global_step, metrics)
#    2118 if self.control.should_save:
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\transformers\trainer.py:2811, in Trainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    2808 start_time = time.time()
#    2810 eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 2811 output = eval_loop(
#    2812     eval_dataloader,
#    2813     description="Evaluation",
#    2814     # No point gathering the predictions if there are no metrics, otherwise we defer to
#    2815     # self.args.prediction_loss_only
#    2816     prediction_loss_only=True if self.compute_metrics is None else None,
#    2817     ignore_keys=ignore_keys,
#    2818     metric_key_prefix=metric_key_prefix,
#    2819 )
#    2821 total_batch_size = self.args.eval_batch_size * self.args.world_size
#    2822 output.metrics.update(
#    2823     speed_metrics(
#    2824         metric_key_prefix,
#    (...)
#    2828     )
#    2829 )
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\transformers\trainer.py:2979, in Trainer.evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    2977 observed_num_examples = 0
#    2978 # Main evaluation loop
# -> 2979 for step, inputs in enumerate(dataloader):
#    2980     # Update the observed num examples
#    2981     observed_batch_size = find_batch_size(inputs)
#    2982     if observed_batch_size is not None:
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\torch\utils\data\dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\torch\utils\data\dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\torch\utils\data\_utils\fetch.py:58, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\torch\utils\data\_utils\fetch.py:58, in <listcomp>(.0)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\datasets\arrow_dataset.py:2356, in Dataset.__getitem__(self, key)
#    2354 def __getitem__(self, key):  # noqa: F811
#    2355     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2356     return self._getitem(
#    2357         key,
#    2358     )
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\datasets\arrow_dataset.py:2341, in Dataset._getitem(self, key, decoded, **kwargs)
#    2339 formatter = get_formatter(format_type, features=self.features, decoded=decoded, **format_kwargs)
#    2340 pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
# -> 2341 formatted_output = format_table(
#    2342     pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    2343 )
#    2344 return formatted_output
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\datasets\formatting\formatting.py:509, in format_table(table, key, formatter, format_columns, output_all_columns)
#     507 python_formatter = PythonFormatter(features=None)
#     508 if format_columns is None:
# --> 509     return formatter(pa_table, query_type=query_type)
#     510 elif query_type == "column":
#     511     if key in format_columns:
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\datasets\formatting\formatting.py:282, in Formatter.__call__(self, pa_table, query_type)
#     280 def __call__(self, pa_table: pa.Table, query_type: str) -> Union[RowFormat, ColumnFormat, BatchFormat]:
#     281     if query_type == "row":
# --> 282         return self.format_row(pa_table)
#     283     elif query_type == "column":
#     284         return self.format_column(pa_table)
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\datasets\formatting\formatting.py:364, in CustomFormatter.format_row(self, pa_table)
#     363 def format_row(self, pa_table: pa.Table) -> dict:
# --> 364     formatted_batch = self.format_batch(pa_table)
#     365     try:
#     366         return _unnest(formatted_batch)
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\datasets\formatting\formatting.py:394, in CustomFormatter.format_batch(self, pa_table)
#     392 batch = self.python_arrow_extractor().extract_batch(pa_table)
#     393 if self.decoded:
# --> 394     batch = self.python_features_decoder.decode_batch(batch)
#     395 return self.transform(batch)
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\datasets\formatting\formatting.py:228, in PythonFeaturesDecoder.decode_batch(self, batch)
#     227 def decode_batch(self, batch: dict) -> dict:
# --> 228     return self.features.decode_batch(batch) if self.features else batch
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\datasets\features\features.py:1831, in Features.decode_batch(self, batch)
#    1828 decoded_batch = {}
#    1829 for column_name, column in batch.items():
#    1830     decoded_batch[column_name] = (
# -> 1831         [decode_nested_example(self[column_name], value) if value is not None else None for value in column]
#    1832         if self._column_requires_decoding[column_name]
#    1833         else column
#    1834     )
#    1835 return decoded_batch
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\datasets\features\features.py:1831, in <listcomp>(.0)
#    1828 decoded_batch = {}
#    1829 for column_name, column in batch.items():
#    1830     decoded_batch[column_name] = (
# -> 1831         [decode_nested_example(self[column_name], value) if value is not None else None for value in column]
#    1832         if self._column_requires_decoding[column_name]
#    1833         else column
#    1834     )
#    1835 return decoded_batch
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\datasets\features\features.py:1262, in decode_nested_example(schema, obj, token_per_repo_id)
#    1259 # Object with special decoding:
#    1260 elif isinstance(schema, (Audio, Image)):
#    1261     # we pass the token to read and decode files from private repositories in streaming mode
# -> 1262     return schema.decode_example(obj, token_per_repo_id=token_per_repo_id) if obj is not None else None
#    1263 return obj
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\datasets\features\image.py:153, in Image.decode_example(self, value, token_per_repo_id)
#     151 else:
#     152     image = PIL.Image.open(BytesIO(bytes_))
# --> 153 image.load()  # to avoid "Too many open files" errors
#     154 return image
#
# File ~\PycharmProjects\plant-diseases-identification\venv\lib\site-packages\PIL\ImageFile.py:260, in ImageFile.load(self)
#     254         raise OSError(
#     255             "image file is truncated "
#     256             f"({len(b)} bytes not processed)"
#     257         )
#     259 b = b + s
# --> 260 n, err_code = decoder.decode(b)
#     261 if n < 0:
#     262     break
#
# KeyboardInterrupt:
